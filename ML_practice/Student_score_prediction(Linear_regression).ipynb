# %% [markdown]
# ## Student Score Prediction

# %% [markdown]
# ### Step 1: Create the Dataset

# %%
import pandas as pd

# %%
data ={
        'study_hours':[2,4,6,8,10],
        'score':[35,55,75,90,98]
                 }

# %%
df = pd.DataFrame(data)
df
# Out:
#    study_hours  score
# 0            2     35
# 1            4     55
# 2            6     75
# 3            8     90
# 4           10     98

# %% [markdown]
# ### Step 2: Split Features and Target
# * Features --->Input

# %%
x = df[["study_hours"]]
y = df["score"]

# %% [markdown]
# ### Step 3: Train the Model

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(x,y)
# Out:
# LinearRegression()

# %% [markdown]
# ### Step 4: Make Predictions

# %%
a = int(input("Enter a study_hours:"))
pred = model.predict([[a]])
print(pred)
# Out:
# Enter a study_hours: 8
# [86.7]
# D:\anaconda\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %% [markdown]
# ### Step 5: Visualize

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(x,y)
plt.plot(x,model.predict(x))
plt.show()
