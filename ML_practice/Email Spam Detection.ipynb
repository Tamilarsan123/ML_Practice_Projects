# %% [markdown]
# # `Email Spam Detection
#
# ## Goal: Predict whether an email is Spam or Not Spam.
#
# ### This is a Classification problem.
#
# * 1 → Spam
# * 0 → Not Spam

# %% [markdown]
# # Workflow Diagram
# * Email Message
#       │
#       ▼
# * Text Preprocessing
#       │
#       ▼
# * Convert Text to Numbers
#  (CountVectorizer/TfidfVectorizer)
#       │
#       ▼
#  * Train Model
#  (Naive Bayes)
#       │
#       ▼
#  * Predict
#       │
#       ▼
#  * Spam or Not Spam

# %% [markdown]
# ## Step 1: Create Dataset

# %%
import pandas as pd 

data = {
     'Message': [
        'Win money now',
        'Claim your prize',
        'Meeting at 5 PM',
        'Project update attached',
        'Congratulations you won a lottery',
        'Call me tomorrow'
    ],
    'Spam': [1, 1, 0, 0, 1, 0]
}

data
# Out:
# {'Message': ['Win money now',
#   'Claim your prize',
#   'Meeting at 5 PM',
#   'Project update attached',
#   'Congratulations you won a lottery',
#   'Call me tomorrow'],
#  'Spam': [1, 1, 0, 0, 1, 0]}

# %%
df = pd.DataFrame(data)
df
# Out:
#                              Message  Spam
# 0                      Win money now     1
# 1                   Claim your prize     1
# 2                    Meeting at 5 PM     0
# 3            Project update attached     0
# 4  Congratulations you won a lottery     1
# 5                   Call me tomorrow     0

# %% [markdown]
# ## Step 2:Split Feature and Target

# %%
x = df['Message']
y = df['Spam']

# %% [markdown]
# ## Step 3:Convert Text to Numbers

# %%
from sklearn.feature_extraction.text import CountVectorizer
vectorizer = CountVectorizer()
x_vector = vectorizer.fit_transform(x)

# %% [markdown]
# ## Step 4:Train the model

# %%
from sklearn.naive_bayes import MultinomialNB
model = MultinomialNB()
model.fit(x_vector,y)
# Out:
# MultinomialNB()

# %% [markdown]
# ## Step 3:Predict

# %%
new_email = ['You won a free prize']
new_email_vector = vectorizer.transform(new_email)
prediction = model.predict(new_email_vector)
print(prediction)
# Out:
# [1]
